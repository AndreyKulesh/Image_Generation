# %% [markdown]
# <a href="https://colab.research.google.com/github/AndreyKulesh/Image_Generation/blob/main/%D0%93%D0%B5%D0%BD%D0%B5%D1%80%D0%B0%D1%86%D0%B8%D1%8F_video.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Установка библиотек**

# %%
# библиотеки

# %% [markdown]
# # **Импорты**

# %%
# импорты

# %% [markdown]
# # **Код**
